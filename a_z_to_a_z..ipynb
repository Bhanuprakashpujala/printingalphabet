# %%
# USING WHILE LOOP AND IF CONDITION PRINTING THE STRUCTURE OF CAPITAL AND SMALL ALPHABETS.
alphabet=input("ENETER THE ALPHABET TO PRINT  ")
print("YOU HAVE CHOOSEN THAT IS  ",alphabet)
a=1
if alphabet== "A":
    while a<=6:
        if a==1:
            print("************")
        elif a==2:
            print("*          *")
        elif a==3:
            print("*          *")
        elif a==4:
            print("************")
        elif a==5:
            print("*          *")
        elif a==6:
            print("*          *")
        a+=1
elif alphabet=="B":
   
 while a<10:
    if a==1:
        print("**********")
    elif a==2:
        print("*         *")
    elif a==3:
        print("*         *")
    elif a==4:
        print("*       *")
    elif a==5:
        print("******")
    elif a==6:
        print("*      *")
    elif a==7:
        print("*        *") 
    elif a==8:
        print("*        *") 
    elif a==9:
        print("*********")
    a=a+1
elif alphabet=="c":
    while a<=5:
        if a==1:
            print("* * * * *")
        elif a==2:
            print("*")
        elif a==3:
            print("*")
        elif a==4:
            print("*")
        elif a==5:
            print("* * * * *")
        a=a+1
elif  alphabet=="D":
    while a<=5:
        if a==1:
            print("******* ")
        elif a==2:
            print("*       *")
        elif a==3:
            print("*       *")
        elif a==4:
            print("******* ")
        elif a==5:
            print("")
        a=a+1
elif alphabet=="E":
    while a<10:
        if a==1:
            print("**********")
        elif a==2:
            print("*")
        elif a==3:
            print("*")
        elif a==4:
            print("*")
        elif a==5:
            print("**********")
        elif a==6:
            print("*")
        elif a==7:
            print("*") 
        elif a==8:
            print("***********")
        a=a+1
elif alphabet=="F":
    while a<10:
        if a==1:
            print("**********")
        elif a==2:
            print("*")
        elif a==3:
            print("*")
        elif a==4:
            print("*")
        elif a==5:
            print("**********")
        elif a==6:
            print("*")
        elif a==7:
            print("*") 
        elif a==8:
            print("*")
        a=a+1
elif alphabet=="G":
    while a<10:
        if a==1:
            print("**********")
        elif a==2:
            print("*")
        elif a==3:
            print("*")
        elif a==4:
            print("*     ********")
        elif a==5:
            print("*        *   *")
        elif a==6:
            print("**********   *")
        a+=1
elif alphabet=="H":
    while a<10:
        if a==1:
            print("*                 *")
        elif a==2:
             print("*                 *")
        elif a==3:
             print("*                 *")
        elif a==4:
             print("*******************")
        elif a==5:
             print("*                 *")
        elif a==6:
            print("*                 *")
        elif a==7:
            print("*                 * ")
        a=a+1
elif alphabet=="I":
    while a<8:
        if a==1:
            print("**************")
        elif a==2:
            print("     **")
        elif a==3:
            print("     **")
        elif a==4:
            print("     **")
        elif a==5:
            print("     **")
        elif a==6:
            print("*************")
        a+=1
elif alphabet=="J":
    while a<8:
        if a==1:
            print("**************")
        elif a==2:
            print("     **")
        elif a==3:
            print("     **")
        elif a==4:
            print("     **")
        elif a==5:
            print(" **  **")
        elif a==6:
            print(" ******")
        a+=1
elif alphabet=="K":
    while a<10:
        if a==1:
            print("*")
        elif a==2:
            print("*        *")
        elif a==3:
            print("*      *")
        elif a==4:
            print("*     *")
        elif a==5:
            print("*   *")
        elif a==6:
            print("**")
        elif a==7:
            print("*   *")
        elif a==8:
            print("*      *")
        elif a==9:
            print("*        *")
        a+=1
elif alphabet=="L":
    while a<10:
        if a==1:
            print("*")
        elif a==2:
            print("*")
        elif a==3:
            print("*")
        elif a==4:
            print("*")
        elif a==5:
            print("*")
        elif a==6:
            print("*")
        elif a==7:
            print("**********")
        a+=1
elif alphabet=="M":
    while a<=5:
        if a==1:
            print("**          **")
        elif a==2:
            print("*  *       * *")
        elif a==3:
            print("*    *   *   *")
        elif a==4:
            print("*     **     *")
        elif a==5:
            print("*            *")
        a+=1
elif alphabet=="N":
    while a<10:
        if a==1:
            print("**                *")
        elif a==2:
            print("*  *              *")
        elif a==3:
            print("*     *           *")
        elif a==4:
            print("*       *         *")
        elif a==5:
            print("*          *      *")
        elif a==6:
            print("*              *  *")
        elif a==7:
            print("*                 * ")
        a=a+1
elif alphabet=="O":
    while a<=5:
        if a==1:
            print(" ****** ")
        elif a==2:
            print("*       *")
        elif a==3:
            print("*       *")
        elif a==4:
            print(" ***** * ")
        elif a==5:
            print("")
        a=a+1
elif alphabet=="P":
    while a<10:
        if a==1:
            print("**********")
        elif a==2:
            print("*        *")
        elif a==3:
            print("*        *")
        elif a==4:
            print("*        *")
        elif a==5:
            print("**********")
        elif a==6:
            print("*")
        elif a==7:
            print("*") 
        elif a==8:
            print("*")
        a=a+1
elif alphabet=="Q":
    while a<=5:
        if a==1:
            print(" ****** ")
        elif a==2:
            print("*       *")
        elif a==3:
            print("*    *  *")
        elif a==4:
            print(" ***** * ")
        elif a==5:
            print("         *")
        a=a+1
elif alphabet=="R":
    while a<10:
        if a==1:
            print("***********")
        elif a==2:
            print("*        *")
        elif a==3:
            print("*       *")
        elif a==4:
            print("*      *")
        elif a==5:
            print("*     *")
        elif a==6:
            print("******")
        elif a==7:
            print("*     *")
        elif a==8:
            print("*       *")
        elif a==9:
            print("*         *")
        a+=1
elif alphabet=="S":
    while a<10:
        if a==1:
            print(" ****** ")
        elif a==2:
            print("*       ") 
        elif a==3:
            print(" ****** ")
        elif a==4:
            print("       *")
        elif a==5:
            print(" ******")
        a+=1
elif alphabet=="T":
    while a<8:
        if a==1:
            print("**************")
        elif a==2:
            print("     **")
        elif a==3:
            print("     **")
        elif a==4:
            print("     **")
        elif a==5:
            print("     **")
        elif a==6:
            print("     **")
        a+=1
elif alphabet=="U":
    while a<=6:
        if a==1:
            print("*          *")
        elif a==2:
            print("*          *")
        elif a==3:
            print("*          *")
        elif a==4:
            print("*          *")
        elif a==5:
            print("*          *")
        elif a==6:
            print("************")
        a+=1
elif alphabet=="V":
    while a<12:
        if a==1:
            print("*          *")
        elif a==2:
            print(" *        *")
        elif a==3:
            print("  *      *")
        elif a==4:
            print("   *    *")
        elif a==5:
            print("    *  *")
        elif a==6:
            print("     **")
        a+=1
elif alphabet=="W":
    while a<=5:
        if a==1:
            print("*          *")
        elif a==2:
            print("*    *     *")
        elif a==3:
            print("*  *   *   *")
        elif a==4:
            print("* *      * *")
        elif a==5:
            print("**        **")
        a+=1
elif alphabet=="X":
    while a<=11:
        if a==1:
            print("*          *")
        elif a==2:
            print(" *        *")
        elif a==3:
            print("  *      *")
        elif a==4:
            print("   *    *")
        elif a==5:
            print("    *  *")
        elif a==6:
            print("     **")
        elif a==7:
            print("    *  *")
        elif a==8:
            print("   *    *")
        elif a==9:
            print("  *      *")
        elif a==10:
            print(" *        *")
        elif a==11:
            print("*          *")
        a+=1
elif alphabet=="Y":
    while a<10:
        if a==1:
            print("*          *")
        elif a==2:
            print(" *        *")
        elif a==3:
            print("  *      *")
        elif a==4:
            print("   *    *")
        elif a==5:
            print("    *  *")
        elif a==6:
            print("     **")
        elif a==7:
            print("     **")
        elif a==8:
            print("     **")
        elif a==9:
            print("     **")
        a+=1
elif alphabet=="Z":
    while a<8:
        if a==1:
            print("**********")
        elif a==2:
            print("        *")
        elif a==3:
            print("       *")
        elif a==4:
            print("      *")
        elif a==5: 
            print("     *")
        elif a==6:
            print("    *")
        elif a==7:
            print("    ************")
        a+=1
elif alphabet=="a":
    while a<=5:
        if a==1:
            print("* * * *")
        elif a==2:
            print("*     *")
        elif a==3:
            print("*     * * ")
        elif a==4:
            print("* * * *   **")
        a=a+1
elif alphabet=="b":
    while a<=5:
        if a==1:
            print("*")
        elif a==2:
            print("*")
        elif a==3:
            print("* * * *")
        elif a==4:
            print("*     *")
        elif a==5:
            print("* * * *")
        a=a+1
elif alphabet=="c":
    a=1
    while a<=6:
        if a==1:
            print("* * * * *")
        elif a==2:
            print("*")
        elif a==3:
            print("*")
        elif a==4:
            print("*")
        elif a==5:
            print("* * * * *")
        elif a==6:
            print(" ")
        a+=1
elif alphabet=="d":
    while a<=5:
        if a==1:
            print("      *")
        elif a==2:
            print("      *")
        elif a==3:
            print("* * * *")
        elif a==4:
            print("*     *")
        elif a==5:
            print("* * * *")
        a=a+1
          
elif alphabet=="e":
    while a<=5:
        if a==1:
            print("* * * * *")
        elif a==2:
            print("*       *")
        elif a==3:
            print("* * * * *")
        elif a==4:
            print("*")
        elif a==5:
            print("* * * * *")
        a=a+1
elif alphabet=="f":
    while a<=6:
        if a==1:
            print("  * * * *")
        elif a==2:
            print("  *     *")
        elif a==3:
            print("  *")
        elif a==4:
            print("* * * * ")
        elif a==5:
            print("  *")
        elif a==6:
            print("  *")
        a=a+1
elif alphabet=="g":
    while a<=6:
        if a==1:
            print("* * * * ")
        elif a==2:
            print("*     *")
        elif a==3:
            print("* * * *")
        elif a==4:
            print("      *")
        elif a==5:
            print("*     *")
        elif a==6:
            print("* * * *")
        a=a+1
elif alphabet=="h":
    while a<=5:
        if a==1:
            print("*")
        elif a==2:
            print("*")
        elif a==3:
            print("* * * *")
        elif a==4:
            print("*     *")
        elif a==5:
            print("*     *")
        a=a+1
elif alphabet=="i":
    a=1
    while a<=6:
        if a==1:
            print("    *")
        elif a==2:
            print("")
        elif a==3:
            print("    *")
        elif a==4:
            print("    *")
        elif a==5:
            print("    *")
        elif a==6:
            print("    *")
        a=a+1
elif alphabet=="j":
    while a<=5:
        if a==1:
            print("     *")
        elif a==2:
            print("     *")
        elif a==3:
            print("     *")
        elif a==4:
            print("*    *")
        elif a==5:
            print("* * * ")
        a=a+1
elif alphabet=="k":
    while a<=5:
        if a==1:
            print("*    *")
        elif a==2:
            print("*  *")
        elif a==3:
            print("**")
        elif a==4:
            print("*  *")
        elif a==5:
            print("*    *")
        a=a+1
elif alphabet=="l":
    while a<=5:
        if a==1:
            print("  * ")
        elif a==2:
            print("  *")
        elif a==3:
            print("  *")
        elif a==4:
            print("  *")
        elif a==5:
            print("  *")
        a=a+1
elif alphabet=="m":
    while a<=5:
        if a==1:
            print("*** * * * * * ")
        elif a==2:
            print("  *   * *   *")
        elif a==3:
            print("  *   ***   *")
        elif a==4:
            print("  *         *")
        elif a==5:
            print("  *         *")
        a=a+1
elif alphabet=="n":
    while a<=5:
        if a==1:
            print("*  * * * * *")
        elif a==2:
            print("* *        *")
        elif a==3:
            print("**         *")
        elif a==4:
            print("*          *")
        elif a==5:
            print("*          *")
        a=a+1
elif alphabet=="o":
    while a<=5:
        if a==1:
            print("* * * *")
        elif a==2:
            print("*     *")
        elif a==3:
            print("*     *")
        elif a==4:
            print("* * * *")
        elif a==5:
            print("")
        a=a+1
elif alphabet=="p":
    while a<=5:
        if a==1:
            print("* * * * *")
        elif a==2:
            print("*       *")
        elif a==3:
            print("* * * * *")
        elif a==4:
            print("*")
        elif a==5:
            print("*")
        a=a+1
    
elif alphabet=="q":
    
    while a<=5:
        if a==1:
            print("* * *")
        elif a==2:
            print("*   *")
        elif a==3:
            print("* * *")
        elif a==4:
            print("    *  *")
        elif a==5:
            print("    *")
        a=a+1
    
elif alphabet=="r":
    while a<=5:
        if a==1:
            print("  *        *")
        elif a==2:
            print("    *    *")
        elif a==3:
            print("      * ")
        elif a==4:
            print("    *   *")
        elif a==5:
            print("   * * * *")
        a=a+1
elif alphabet=="s":
    while a<=5:
        if a==1:
            print("* * * *")
        elif a==2:
            print("*")
        elif a==3:
            print("* * * *")
        elif a==4:
            print("      *")
        elif a==5:
            print("* * * *")
        a=a+1
elif alphabet=="t":
    while a<=5:
        if a==1:
            print("   *")
        elif a==2:
            print("   *")
        elif a==3:
            print("* * * *")
        elif a==4:
            print("   *")
        elif a==5:
            print("   * * * *")
        a=a+1
             
elif alphabet=="u":
    while a<=5:
        if a==1:
            print("*    *")
        elif a==2:
            print("*    *")
        elif a==3:
            print("* * * *")
        elif a==4:
            print("")
        elif a==5:
            print("")
        a=a+1
elif alphabet=="v":
    while a<=5:
        if a==1:
            print("*    *")
        elif a==2:
            print(" *  *")
        elif a==3:
            print("  *")
        elif a==4:
            print("")
        elif a==5:
            print("")
        a=a+1
elif alphabet=="w":
    while a<=5:
        if a==1:
            print("*       *")
        elif a==2:
            print("*       *")
        elif a==3:
            print("*  * *  *")
        elif a==4:
            print("*  * *  *")
        elif a==5:
            print("* *   * * ")
        a=a+1
elif alphabet=="x":
    while a<=5:
        if a==1:
            print(" *   *")
        elif a==2:
            print("  * *")
        elif a==3:
            print("   *")
        elif a==4:
            print("  * *")
        elif a==5:
            print(" *   *")
        a=a+1
elif alphabet=="y":
    while a<=5:
        if a==1:
            print("*     *")
        elif a==2:
            print("*     *")
        elif a==3:
            print("* * * *")
        elif a==4:
            print("      *")
        elif a==5:
            print("* * * *")
        a=a+1
elif alphabet=="z":
    while a<=6:
        if a==1:
            print("* * * *")
        elif a==2:
            print("      *")
        elif a==3:
            print("* * * ")
        elif a==4:
            print("    * *")
        elif a==5:
            print("* * * *  *")
        elif a==6:
            print("       * ")
        a=a+1
else:
    print("you have to enter capital or small alphabets")
# Out:
# ENETER THE ALPHABET TO PRINT  1
# YOU HAVE CHOOSEN THAT IS   1
# you have to enter capital or small alphabets
